# %% [markdown]
# <div style="font-family: Arial; color: #5DADE2; text-align: center; font-size: 36px;">
#     <i>Compte Rendu TP 2 Atelier ML</i>
#     </br>
#     </br>
#     <i>Etude de Cas</i>
# </div>
# <div style="font-family: Arial; color: #27AE60 ; font-size: 20px;">
#     <b>Réalisé Par:</b>
# </div>
# <ul style="font-family: Arial; color: #2E86C1 ; font-size: 18px;">
#     <li>Ouhibi Ons</li>
#     <li>Ben Zaied Mouna</li>
# </ul>
# <div style="font-family: Arial; color: #27AE60 ; text-align: left; padding-left: 20px; font-size: 15px;">
#     <b>RT4 Groupe 2</b>
# </div>

# %% [markdown]
# </br>
# <div style="font-family: Arial; color: black ; font-size: 20px;">
#     <b>On s'interesse à la visualisation de la dataset "Ticket Management Dataset- Cybersecurity"  </b>
# </div>
# </br>

# %%
# !pip install openpyxl

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import openpyxl
import datetime
import seaborn as sns
# Out:
# Requirement already satisfied: openpyxl in c:\users\mouna\anaconda3\envs\atelier_ml\lib\site-packages (3.1.2)
# Requirement already satisfied: et-xmlfile in c:\users\mouna\anaconda3\envs\atelier_ml\lib\site-packages (from openpyxl) (1.1.0)

# %%
df = pd.read_excel('Ticket Details.xlsx')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 627 entries, 0 to 626
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Ticket No        627 non-null    object
#  1   Priority         627 non-null    object
#  2   State            627 non-null    object
#  3   Category         627 non-null    object
#  4   Sub Category     627 non-null    object
#  5   Skill Team       627 non-null    object
#  6   Hosting          627 non-null    object
#  7   Create Date      627 non-null    datetime64[ns]
#  8   Picked Date      627 non-null    datetime64[ns]
#  9   Completed Date   627 non-null    object
#  10  Assignee         627 non-null    object
#  11  Customer Rating  627 non-null    object
#  12  Outcome          627 non-null    object
#  13  Escalated        59 non-null     object
#  14  Reached via      627 non-null    object
# dtypes: datetime64[ns](2), object(13)
# memory usage: 73.6+ KB

# %%
df.sample(10)
# Out:
#     Ticket No Priority           State               Category  \
# 245      T314     High  North Carolina  Cyber Security Breach
# 348      T408      Low        Virginia              Data Leak
# 545      T587     High      California           Data Privacy
# 527      T570     High         Georgia           Data Privacy
# 577      T616     High        Virginia           Data Privacy
# 184      T259      Low      Washington     Cyber Consultation
# 429      T481     High           Texas  Cyber Security Breach
# 447      T498     High        New York  Cyber Security Breach
# 76       T160     High      California  Cyber Security Breach
# 205      T278     High        Virginia           Data Privacy
#
#            Sub Category     Skill Team         Hosting         Create Date  \
# 245      Malware Attack      Marketing  On Prem Server 2021-06-25 16:12:57
# 348            Phishing             IT    Vendor Cloud 2021-08-14 00:01:01
# 545             PCI-DSS             HR  On Prem Server 2021-11-24 11:23:33
# 527  Privacy Assessment        Finance  On Prem Server 2021-11-17 18:04:28
# 577                GDPR  Manufacturing  On Prem Server 2021-12-13 17:06:07
# 184  Secure Development             HR    Vendor Cloud 2021-05-27 21:00:20
# 429            Firewall  Manufacturing    Vendor Cloud 2021-09-17 13:24:10
# 447      Malware Attack  Manufacturing  On Prem Server 2021-09-27 11:29:21
# 76             Firewall      Marketing    Vendor Cloud 2021-04-22 02:13:54
# 205               HIPAA  Manufacturing  On Prem Server 2021-06-07 23:13:05
#
#             Picked Date       Completed Date   Assignee     Customer Rating  \
# 245 2021-06-25 16:13:32  2021-06-25 22:46:27  Charlotte       Excellent (5)
# 348 2021-08-30 12:34:46  2021-09-07 18:27:42     Robbin       Excellent (5)
# 545 2021-11-24 11:24:11  2021-11-24 11:25:00     Robbin            Good (4)
# 527 2021-11-17 18:11:17  2021-11-19 09:47:48    Charles  Unsatisfactory (2)
# 577 2021-12-13 17:14:13  2021-12-17 19:21:34    Michael    Satisfactory (3)
# 184 2021-05-27 21:00:52  2021-05-27 21:20:08    Martina       Excellent (5)
# 429 2021-09-17 13:24:10  2021-09-17 13:24:10   Veronica       Excellent (5)
# 447 2021-09-27 12:45:51  2021-10-01 17:44:27    Kareema    Satisfactory (3)
# 76  2021-04-22 09:47:12  2021-05-03 09:49:34       Sean       Excellent (5)
# 205 2021-06-08 07:36:11  2021-06-23 19:47:34    Martina  Unsatisfactory (2)
#
#                            Outcome Escalated    Reached via
# 245                       Resolved       NaN  Ticket Portal
# 348  Advised for a risk assessment       NaN  Ticket Portal
# 545                       Resolved       NaN  Ticket Portal
# 527                       Resolved       NaN  Ticket Portal
# 577  Recommended Threat Assessment       NaN  Ticket Portal
# 184  Recommended Threat Assessment       NaN  Ticket Portal
# 429                       Resolved       NaN  Ticket Portal
# 447                       Resolved       NaN           Mail
# 76                        Resolved       NaN  Ticket Portal
# 205  Advised for a risk assessment       Yes  Ticket Portal

# %%
df.isnull().sum()
# Out:
# Ticket No            0
# Priority             0
# State                0
# Category             0
# Sub Category         0
# Skill Team           0
# Hosting              0
# Create Date          0
# Picked Date          0
# Completed Date       0
# Assignee             0
# Customer Rating      0
# Outcome              0
# Escalated          568
# Reached via          0
# dtype: int64

# %%
df['Escalated'].unique() # la colonne de 'Excalated' a des valeurs NaN
# Out:
# array([nan, 'Yes', 'No'], dtype=object)

# %%
# Trouver la valeur most frequent dans la colonne Escalated
most_frequent_value = df['Escalated'].mode()[0]

# Fill missing values with the most frequent value
df['Escalated'].fillna(most_frequent_value, inplace=True)

# Check unique values in the 'Escalated' column after filling missing values
print(df['Escalated'].unique())
# Out:
# ['Yes' 'No']

# %%
df.sample(10)
#La colonne Escalated est maintenant remplie par le most frequent
# Out:
#     Ticket No Priority          State               Category  \
# 456      T506   Medium        Georgia     Cyber Consultation
# 355      T414     High         Kansas     Cyber Consultation
# 276      T342     High   Pennsylvania           Data Privacy
# 52       T139     High  Massachusetts              Data Leak
# 584      T622      Low       Kentucky              Data Leak
# 208      T280      Low          Texas           Data Privacy
# 591       T64     High       New York           Data Privacy
# 450      T500      Low     California           Security Gap
# 595       T68     High     California              Data Leak
# 623       T96     High     California  Cyber Security Breach
#
#            Sub Category     Skill Team         Hosting         Create Date  \
# 456   Access Management             HR    Vendor Cloud 2021-09-29 20:50:04
# 355              BCP/DR      Marketing   On Prem Cloud 2021-08-16 19:51:29
# 276  Privacy Assessment          Legal  On Prem Server 2021-07-14 12:52:50
# 52              Vishing             HR  On Prem Server 2021-04-14 21:46:44
# 584             Vishing             HR  On Prem Server 2021-12-20 15:57:46
# 208             PCI-DSS  Manufacturing   On Prem Cloud 2021-06-08 17:18:12
# 591               HIPAA             IT  On Prem Server 2021-02-18 20:29:44
# 450   Obsolete Software        Finance    Vendor Cloud 2021-09-28 18:44:27
# 595             Vishing             HR  On Prem Server 2021-02-19 18:34:13
# 623            Firewall             IT  On Prem Server 2021-03-12 11:55:31
#
#             Picked Date       Completed Date Assignee     Customer Rating  \
# 456 2021-09-29 20:56:31  2021-10-07 21:59:13  Martina       Excellent (5)
# 355 2021-08-16 20:44:51  2021-08-20 18:18:12  Martina       Excellent (5)
# 276 2021-07-14 12:54:05  2021-07-14 12:55:55  Charles       Excellent (5)
# 52  2021-04-14 21:49:55  2021-04-19 18:13:18  Michael       Excellent (5)
# 584 2021-12-20 15:58:34  2022-02-17 17:35:35   Aleena            Good (4)
# 208 2021-06-08 17:27:06  2021-06-24 09:52:51      Bob  Unsatisfactory (2)
# 591 2021-02-18 20:36:58  2021-06-02 10:13:11  Charles       Excellent (5)
# 450 2021-09-29 10:33:01  2021-10-01 11:17:12  Charles    Satisfactory (3)
# 595 2021-02-19 18:37:33  2021-02-24 12:17:12  Martina       Excellent (5)
# 623 2021-03-12 11:58:38  2021-03-17 09:47:17    Benny       Excellent (5)
#
#                            Outcome Escalated    Reached via
# 456                       Resolved       Yes  Ticket Portal
# 355  Advised for a risk assessment       Yes           Mail
# 276                       Resolved       Yes  Personal Call
# 52   Advised for a risk assessment       Yes  Ticket Portal
# 584  Recommended Threat Assessment       Yes  Ticket Portal
# 208  Recommended Threat Assessment       Yes  Ticket Portal
# 591  Recommended Threat Assessment       Yes           Mail
# 450  Advised for a risk assessment       Yes  Personal Call
# 595  Recommended Threat Assessment       Yes  Ticket Portal
# 623                       Resolved       Yes  Personal Call

# %% [markdown]
# </br>
# <div style="font-family: Arial; color: #27AE60 ; font-size: 45px;">
#     <b>Affichage des tickets par Priorité </b>
# </div>
# </br>

# %%
# Supposons que df est votre DataFrame contenant les données
priority_group = df.groupby('Priority')['Ticket No'].count().sort_values(ascending=False).reset_index()

# Utilisation d'une palette de couleurs personnalisée
custom_colors = sns.color_palette('pastel', n_colors=len(priority_group))

# Tracé avec Seaborn
plt.figure(figsize=(10, 6))
ax = sns.barplot(x='Priority', y='Ticket No', data=priority_group, hue='Priority', palette=custom_colors, dodge=False, legend=False)

# Boucle pour ajouter des étiquettes aux barres
for index, row in priority_group.iterrows():
    ax.text(row.name, row['Ticket No'], f"{row['Ticket No']:,}", ha='center', va='bottom', fontsize=12)

# Personnalisation du graphique
plt.title("Nombre de tickets par priorité", fontsize=16)
plt.xlabel("Priorité", fontsize=14)
plt.ylabel("Nombre de tickets", fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Affichage du graphique
plt.show()

# %% [markdown]
# </br>
# <div style="font-family: Arial; color: #27AE60 ; font-size: 45px;">
#     <b>Affichage des tickets par Catégorie </b>
# </div>
# </br>

# %%
# Supposons que category_group est le DataFrame regroupé
category_group = df.groupby('Category')['Ticket No'].count().sort_values(ascending=False).reset_index()

# Utilisation d'une palette de couleurs personnalisée
custom_colors = sns.color_palette('pastel', n_colors=len(category_group))

# Tracé avec Seaborn
plt.figure(figsize=(10, 5))
ax = sns.barplot(x='Category', y='Ticket No', data=category_group, hue='Category', palette=custom_colors, dodge=False, legend=False)

# Ajout d'étiquettes aux barres
for index, row in category_group.iterrows():
    ax.text(row.name, row['Ticket No'], row['Ticket No'], ha='center', va='bottom', fontsize=12)

# Personnalisation du graphique
plt.title("Nombre de tickets par catégorie", fontsize=16)
plt.xlabel("Catégorie", fontsize=14)
plt.ylabel("Nombre de tickets", fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Affichage du graphique
plt.show()

# %% [markdown]
# </br>
# <div style="font-family: Arial; color: #27AE60 ; font-size: 45px;">
#     <b>Affichage des tickets par sous-catégorie </b>
# </div>
# </br>

# %%
# Supposons que subcategory_group est le DataFrame regroupé
subcategory_group = df.groupby('Sub Category')['Ticket No'].count().sort_values(ascending=False).reset_index()

# Utilisation d'une palette de couleurs personnalisée
custom_colors = sns.color_palette('pastel', n_colors=len(subcategory_group))

# Tracé avec Seaborn
plt.figure(figsize=(15, 5))
ax = sns.barplot(x='Sub Category', y='Ticket No', data=subcategory_group, hue='Sub Category', palette=custom_colors, dodge=False, legend=False)

# Ajout d'étiquettes aux barres
for index, row in subcategory_group.iterrows():
    ax.text(row.name, row['Ticket No'], row['Ticket No'], ha='center', va='bottom', fontsize=10)

# Personnalisation du graphique
plt.title("Nombre de tickets par sous-catégorie", fontsize=16)
plt.xlabel("Sous-catégorie", fontsize=14)
plt.ylabel("Nombre de tickets", fontsize=14)
plt.xticks(rotation=90, fontsize=10)
plt.yticks(fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Affichage du graphique
plt.show()

# %% [markdown]
# </br>
# <div style="font-family: Arial; color: #27AE60 ; font-size: 45px;">
#     <b>Affichage des tickets par équipe </b>
# </div>
# </br>

# %%
# Supposons que team_group est le DataFrame regroupé
team_group = df.groupby('Skill Team')['Ticket No'].count().sort_values(ascending=False).reset_index()

# Tracé du graphique circulaire
plt.figure(figsize=(10, 5))
colors = plt.cm.Paired.colors
_, _, autotexts = plt.pie(team_group['Ticket No'], labels=team_group['Skill Team'], autopct="%.0f%%", colors=colors, startangle=90, counterclock=False)
plt.title("Pourcentage de tickets par équipe de compétences", fontsize=16)

# Ajout de labels pour chaque tranche
for autotext in autotexts:
    autotext.set_color('white')
    autotext.set_fontsize(12)

# Affichage d'un cercle parfait
plt.axis('equal')

# Affichage du graphique
plt.show()

# %% [markdown]
# </br>
# <div style="font-family: Arial; color: #27AE60 ; font-size: 45px;">
#     <b>Affichage des tickets par mois </b>
# </div>
# </br>

# %%
# Grouper par mois
month_group = df.groupby(df['Create Date'].dt.month)['Ticket No'].count().reset_index()

# Utilisation d'une palette de couleurs personnalisée
custom_colors = sns.color_palette('pastel', n_colors=len(month_group))

# Tracé avec Seaborn
plt.figure(figsize=(15, 5))
ax = sns.barplot(data=month_group, x='Create Date', y='Ticket No', hue='Create Date', palette=custom_colors, dodge=False, legend=False)

# Ajout d'étiquettes aux barres
for index, row in month_group.iterrows():
    ax.text(row.name, row['Ticket No'], row['Ticket No'], ha='center', va='bottom', fontsize=12)

# Personnalisation du graphique
plt.title('Nombre de tickets par mois', fontsize=18, fontweight='bold')
plt.xlabel('Mois', fontsize=14, fontweight='bold')
plt.xticks(range(0, 12), ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'], fontsize=12)
plt.ylabel('Nombre de tickets', fontsize=14, fontweight='bold')
plt.yticks(fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Affichage du graphique
plt.show()

# %%
# Création de la table pivot
state_pivot = pd.pivot_table(data=df, index='State', values='Ticket No', aggfunc='count').sort_values('Ticket No', ascending=False)

# Application du style de gradient de couleur
styled_pivot = state_pivot.style.background_gradient(cmap='Blues').set_properties(**{'font-size': '12pt', 'font-family': 'Arial', 'text-align': 'center'})

styled_pivot.set_caption('Nombre de tickets par état').set_table_styles([{'selector': 'caption', 'props': [('color', 'black'), ('font-size', '16pt'), ('font-weight', 'bold')]}])

# Affichage de la table stylée
styled_pivot
# Out:
# <style type="text/css">
# #T_27d94 caption {
#   color: black;
#   font-size: 16pt;
#   font-weight: bold;
# }
# #T_27d94_row0_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
#   font-size: 12pt;
#   font-family: Arial;
#   text-align: center;
# }
# #T_27d94_row1_col0 {
#   background-color: #8abfdd;
#   color: #000000;
#   font-size: 12pt;
#   font-family: Arial;
#   text-align: center;
# }
# #T_27d94_row2_col0 {
#   background-color: #a5cde3;
#   color: #000000;
#   font-size: 12pt;
#   font-family: Arial;
#   text-align: center;
# }
# #T_27d94_row3_col0, #T_27d94_row4_col0 {
#   background-color: #bcd7eb;
#   color: #000000;
#   font-size: 12pt;
#   font-family: Arial;
#   text-align: center;
# }
# #T_27d94_row5_col0 {
#   background-color: #d3e3f3;
#   color: #000000;
#   font-size: 12pt;
#   font-family: Arial;
#   text-align: center;
# }
# #T_27d94_row6_col0 {
#   background-color: #d9e7f5;
#   color: #000000;
#   font-size: 12pt;
#   font-family: Arial;
#   text-align: center;
# }
# #T_27d94_row7_col0, #T_27d94_row8_col0 {
#   background-color: #dce9f6;
#   color: #000000;
#   font-size: 12pt;
#   font-family: Arial;
#   text-align: center;
# }
# #T_27d94_row9_col0 {
#   background-color: #ddeaf7;
#   color: #000000;
#   font-size: 12pt;
#   font-family: Arial;
#   text-align: center;
# }
# #T_27d94_row10_col0, #T_27d94_row11_col0 {
#   background-color: #e2edf8;
#   color: #000000;
#   font-size: 12pt;
#   font-family: Arial;
#   text-align: center;
# }
# #T_27d94_row12_col0, #T_27d94_row13_col0 {
#   background-color: #e3eef9;
#   color: #000000;
#   font-size: 12pt;
#   font-family: Arial;
#   text-align: center;
# }
# #T_27d94_row14_col0 {
#   background-color: #e5eff9;
#   color: #000000;
#   font-size: 12pt;
#   font-family: Arial;
#   text-align: center;
# }
# #T_27d94_row15_col0 {
#   background-color: #e7f0fa;
#   color: #000000;
#   font-size: 12pt;
#   font-family: Arial;
#   text-align: center;
# }
# #T_27d94_row16_col0 {
#   background-color: #e8f1fa;
#   color: #000000;
#   font-size: 12pt;
#   font-family: Arial;
#   text-align: center;
# }
# #T_27d94_row17_col0 {
#   background-color: #eaf2fb;
#   color: #000000;
#   font-size: 12pt;
#   font-family: Arial;
#   text-align: center;
# }
# #T_27d94_row18_col0, #T_27d94_row19_col0 {
#   background-color: #ebf3fb;
#   color: #000000;
#   font-size: 12pt;
#   font-family: Arial;
#   text-align: center;
# }
# #T_27d94_row20_col0, #T_27d94_row21_col0, #T_27d94_row22_col0, #T_27d94_row23_col0 {
#   background-color: #edf4fc;
#   color: #000000;
#   font-size: 12pt;
#   font-family: Arial;
#   text-align: center;
# }
# #T_27d94_row24_col0 {
#   background-color: #eef5fc;
#   color: #000000;
#   font-size: 12pt;
#   font-family: Arial;
#   text-align: center;
# }
# #T_27d94_row25_col0, #T_27d94_row26_col0 {
#   background-color: #f0f6fd;
#   color: #000000;
#   font-size: 12pt;
#   font-family: Arial;
#   text-align: center;
# }
# #T_27d94_row27_col0, #T_27d94_row28_col0, #T_27d94_row29_col0 {
#   background-color: #f2f7fd;
#   color: #000000;
#   font-size: 12pt;
#   font-family: Arial;
#   text-align: center;
# }
# #T_27d94_row30_col0 {
#   background-color: #f3f8fe;
#   color: #000000;
#   font-size: 12pt;
#   font-family: Arial;
#   text-align: center;
# }
# #T_27d94_row31_col0, #T_27d94_row32_col0, #T_27d94_row33_col0 {
#   background-color: #f5f9fe;
#   color: #000000;
#   font-size: 12pt;
#   font-family: Arial;
#   text-align: center;
# }
# #T_27d94_row34_col0, #T_27d94_row35_col0, #T_27d94_row36_col0 {
#   background-color: #f6faff;
#   color: #000000;
#   font-size: 12pt;
#   font-family: Arial;
#   text-align: center;
# }
# #T_27d94_row37_col0, #T_27d94_row38_col0, #T_27d94_row39_col0, #T_27d94_row40_col0, #T_27d94_row41_col0, #T_27d94_row42_col0, #T_27d94_row43_col0, #T_27d94_row44_col0 {
#   background-color: #f7fbff;
#   color: #000000;
#   font-size: 12pt;
#   font-family: Arial;
#   text-align: center;
# }
# </style>
# <table id="T_27d94">
#   <caption>Nombre de tickets par état</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_27d94_level0_col0" class="col_heading level0 col0" >Ticket No</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >State</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_27d94_level0_row0" class="row_heading level0 row0" >California</th>
#       <td id="T_27d94_row0_col0" class="data row0 col0" >131</td>
#     </tr>
#     <tr>
#       <th id="T_27d94_level0_row1" class="row_heading level0 row1" >New York</th>
#       <td id="T_27d94_row1_col0" class="data row1 col0" >56</td>
#     </tr>
#     <tr>
#       <th id="T_27d94_level0_row2" class="row_heading level0 row2" >Florida</th>
#       <td id="T_27d94_row2_col0" class="data row2 col0" >47</td>
#     </tr>
#     <tr>
#       <th id="T_27d94_level0_row3" class="row_heading level0 row3" >Texas</th>
#       <td id="T_27d94_row3_col0" class="data row3 col0" >38</td>
#     </tr>
#     <tr>
#       <th id="T_27d94_level0_row4" class="row_heading level0 row4" >Virginia</th>
#       <td id="T_27d94_row4_col0" class="data row4 col0" >38</td>
#     </tr>
#     <tr>
#       <th id="T_27d94_level0_row5" class="row_heading level0 row5" >Illinois</th>
#       <td id="T_27d94_row5_col0" class="data row5 col0" >25</td>
#     </tr>
#     <tr>
#       <th id="T_27d94_level0_row6" class="row_heading level0 row6" >Utah</th>
#       <td id="T_27d94_row6_col0" class="data row6 col0" >21</td>
#     </tr>
#     <tr>
#       <th id="T_27d94_level0_row7" class="row_heading level0 row7" >Georgia</th>
#       <td id="T_27d94_row7_col0" class="data row7 col0" >19</td>
#     </tr>
#     <tr>
#       <th id="T_27d94_level0_row8" class="row_heading level0 row8" >New Jersey</th>
#       <td id="T_27d94_row8_col0" class="data row8 col0" >19</td>
#     </tr>
#     <tr>
#       <th id="T_27d94_level0_row9" class="row_heading level0 row9" >Colorado</th>
#       <td id="T_27d94_row9_col0" class="data row9 col0" >18</td>
#     </tr>
#     <tr>
#       <th id="T_27d94_level0_row10" class="row_heading level0 row10" >Arizona</th>
#       <td id="T_27d94_row10_col0" class="data row10 col0" >15</td>
#     </tr>
#     <tr>
#       <th id="T_27d94_level0_row11" class="row_heading level0 row11" >Massachusetts</th>
#       <td id="T_27d94_row11_col0" class="data row11 col0" >15</td>
#     </tr>
#     <tr>
#       <th id="T_27d94_level0_row12" class="row_heading level0 row12" >North Carolina</th>
#       <td id="T_27d94_row12_col0" class="data row12 col0" >14</td>
#     </tr>
#     <tr>
#       <th id="T_27d94_level0_row13" class="row_heading level0 row13" >Pennsylvania</th>
#       <td id="T_27d94_row13_col0" class="data row13 col0" >14</td>
#     </tr>
#     <tr>
#       <th id="T_27d94_level0_row14" class="row_heading level0 row14" >Ohio</th>
#       <td id="T_27d94_row14_col0" class="data row14 col0" >13</td>
#     </tr>
#     <tr>
#       <th id="T_27d94_level0_row15" class="row_heading level0 row15" >Michigan</th>
#       <td id="T_27d94_row15_col0" class="data row15 col0" >12</td>
#     </tr>
#     <tr>
#       <th id="T_27d94_level0_row16" class="row_heading level0 row16" >Washington</th>
#       <td id="T_27d94_row16_col0" class="data row16 col0" >11</td>
#     </tr>
#     <tr>
#       <th id="T_27d94_level0_row17" class="row_heading level0 row17" >Oregon</th>
#       <td id="T_27d94_row17_col0" class="data row17 col0" >10</td>
#     </tr>
#     <tr>
#       <th id="T_27d94_level0_row18" class="row_heading level0 row18" >District of Columbia</th>
#       <td id="T_27d94_row18_col0" class="data row18 col0" >9</td>
#     </tr>
#     <tr>
#       <th id="T_27d94_level0_row19" class="row_heading level0 row19" >Maryland</th>
#       <td id="T_27d94_row19_col0" class="data row19 col0" >9</td>
#     </tr>
#     <tr>
#       <th id="T_27d94_level0_row20" class="row_heading level0 row20" >Missouri</th>
#       <td id="T_27d94_row20_col0" class="data row20 col0" >8</td>
#     </tr>
#     <tr>
#       <th id="T_27d94_level0_row21" class="row_heading level0 row21" >Wisconsin</th>
#       <td id="T_27d94_row21_col0" class="data row21 col0" >8</td>
#     </tr>
#     <tr>
#       <th id="T_27d94_level0_row22" class="row_heading level0 row22" >Minnesota</th>
#       <td id="T_27d94_row22_col0" class="data row22 col0" >8</td>
#     </tr>
#     <tr>
#       <th id="T_27d94_level0_row23" class="row_heading level0 row23" >Tennessee</th>
#       <td id="T_27d94_

# %% [markdown]
# </br>
# <div style="font-family: Arial; color: #27AE60 ; font-size: 45px;">
#     <b>Affichage des tickets par "Assignee" </b>
# </div>
# </br>

# %%
# Création de la table pivot
assignee_pivot = pd.pivot_table(data=df, index=df['Create Date'].dt.month, columns='Assignee', values='Ticket No', aggfunc='count').fillna(0)

# Obtention des noms des assignés à partir de la table pivot
assignees = assignee_pivot.columns

# Définition de la taille de la figure
plt.rcParams['figure.figsize'] = (25, 25)

# Définition d'une palette de couleurs personnalisée
colors = sns.color_palette('Paired', len(assignees))

# Boucle pour tracer les sous-graphiques avec des couleurs personnalisées
for i, assignee in enumerate(assignees, 1):
    ax = plt.subplot(5, 3, i)
    assignee_pivot[assignee].plot(kind='bar', color=colors)
    plt.xticks(range(0, 12), ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
    ax.set_title(assignee, fontsize=16, fontweight='bold', ha='center', va='center')
    ax.set_xlabel('Month', fontsize=12, fontweight='bold', labelpad=10)
    ax.set_ylabel('#Tickets', fontsize=12, fontweight='bold', labelpad=10)
    ax.title.set_position([0.5, 1.05])
    ax.xaxis.set_label_coords(0.5, -0.1)

# Affichage des sous-graphiques
plt.tight_layout()
plt.show()

# %% [markdown]
# </br>
# <div style="font-family: Arial; color: #27AE60 ; font-size: 20px;">
#     <b>Conclusion:  </b>
# </div>
# </br>
#
# <div>
# <p> Après avoir consulté la dataset, on remarque que certains employés gèrent un nombre inférieur de tickets par rapport aux autres ce qui pourrait signaler la nécessité de  réévaluer la répartition des charges de travail.
#
# On remarque aussi une attention particulière aux sous-catégories de "HIPAA" et "Incider Threat" ou catégories spécifiques comme "Data Privacy" et "Cyber Consultation" par rapport aux autres indiquent une demande croissante dans ces domaines, nécessitant une analyse approfondie pour identifier les problèmes et mettre en œuvre des solutions ciblées. Ces deux analyses offrent des opportunités d'amélioration et d'optimisation des processus pour renforcer la productivité de l'équipe et améliorer la qualité globale du service client. </p>
# </div>

# %% [markdown]
# </br>
# <div style="font-family: Arial; color: black ; font-size: 20px;">
#     <b>On s'interesse à la visualisation et l'analyse de la dataset "Global Salary Data"  </b>
# </div>
# </br>

# %%
df = pd.read_csv("salary_data.csv")
df
# Out:
#             country_name continent_name wage_span  median_salary  \
# 0            Afghanistan           Asia   Monthly     853.740000
# 1          Aland Islands         Europe   Monthly    3319.240000
# 2                Albania         Europe   Monthly     832.840000
# 3                Algeria         Africa   Monthly    1148.840000
# 4         American Samoa        Oceania   Monthly    1390.000000
# ..                   ...            ...       ...            ...
# 216  Virgin Islands (US)  North America   Monthly    2380.000000
# 217       Western Sahara         Africa   Monthly     908.560000
# 218                Yemen           Asia   Monthly     120.980000
# 219               Zambia         Africa   Monthly       0.261335
# 220             Zimbabwe         Africa   Monthly     555.402040
#
#      average_salary  lowest_salary  highest_salary
# 0       1001.150000     252.530000     4460.970000
# 1       3858.350000     972.520000    17124.740000
# 2        956.920000     241.220000     4258.490000
# 3       1308.810000     330.110000     5824.180000
# 4       1570.000000     400.000000     6980.000000
# ..              ...            ...             ...
# 216     2710.000000     680.000000    12000.000000
# 217     1011.670000     254.860000     4503.890000
# 218      133.360000      33.620000      594.930000
# 219        0.285524       0.072092        1.271103
# 220      602.376350     151.423050     2674.772000
#
# [221 rows x 7 columns]

# %% [markdown]
# </br>
# <div style="font-family: Arial; color: black ; font-size: 15px;">
#     Après avoir inspecté notre ensemble de données, nous constatons qu'il ne présente pas de valeurs manquantes ni d'irrégularités qui nécessiteraient un nettoyage approfondi, ce qui nous permet de procéder directement à l'exploration et à l'analyse des données.
# </div>
# </br>
